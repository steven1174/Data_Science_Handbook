# %% [markdown]
# <a href="https://colab.research.google.com/github/steven1174/Data_Science_Handbook/blob/main/5.Computation%20on%20Arrays%20Broadcasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computation on Arrays: Broadcasting
# ## Introducing Broadcasting

# %%
import numpy as np

a = np.array([0, 1, 2])
b = np.array([5, 5, 5])
a + b
# Out:
# array([5, 6, 7])

# %%
a + 5
# Out:
# array([5, 6, 7])

# %%
M = np.ones((3, 3))
M
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
M + a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.],
#        [1., 2., 3.]])

# %%
a = np.arange(3)
b = np.arange(3)[:, np.newaxis]

print(a)
print(b)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]

# %%
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ## Rules of Broadcasting
# - Rule 1: If the two arrays differ in their number of dimensions, the shape of the one with fewer dimensions is padded with ones on its leading (left) side.
# - Rule 2: If the shape of the two arrays does not match in any dimension, the array with shape equal to 1 in that dimension is stretched to match the other shape.
# - Rule 3: If in any dimension the sizes disagree and neither is equal to 1, an error is raised.

# %% [markdown]
# ### Broadcasting example 1

# %%
M = np.ones((2, 3))
a = np.arange(3)

print(M)
print('\n',a)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]
#
#  [0 1 2]

# %%
M + a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.]])

# %% [markdown]
# ### Broadcasting example 2

# %%
a = np.arange(3).reshape((3, 1))
b = np.arange(3)

print(a)
print('\n',b)
# Out:
# [[0]
#  [1]
#  [2]]
#
#  [0 1 2]

# %%
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %% [markdown]
# ### Broadcasting example 3

# %%
M = np.ones((3, 2))
a = np.arange(3)

print(M)
print('\n',a)
# Out:
# [[1. 1.]
#  [1. 1.]
#  [1. 1.]]
#
#  [0 1 2]

# %%
M + a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-8cac1d547906> in <module>()
# ----> 1 M + a
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %% [markdown]
# ## Broadcasting in Practice
# ### Centering an array

# %%
X = np.random.random((10, 3))
X
# Out:
# array([[0.56073903, 0.29788703, 0.36007246],
#        [0.66272489, 0.71397042, 0.59495851],
#        [0.03550615, 0.03046868, 0.18623843],
#        [0.06447474, 0.50619685, 0.04759112],
#        [0.5216083 , 0.4852253 , 0.74818158],
#        [0.49437593, 0.6297899 , 0.552465  ],
#        [0.69272284, 0.91462505, 0.84943715],
#        [0.20557087, 0.80352277, 0.24989701],
#        [0.02282828, 0.93426525, 0.78363066],
#        [0.90041791, 0.46355092, 0.28779634]])

# %%
Xmean = X.mean(0)
Xmean
# Out:
# array([0.41609689, 0.57795022, 0.46602683])

# %%
X_centered = X - Xmean
X_centered.mean(0)
# Out:
# array([ 8.8817842e-17,  4.4408921e-17, -4.4408921e-17])

# %% [markdown]
# ### Plotting a two-dimensional function

# %%
# x and y have 50 steps from 0 to 5
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 50)[:, np.newaxis]
z = np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(z, origin='lower', extent=[0, 5, 0, 5],cmap='viridis')
plt.colorbar()
